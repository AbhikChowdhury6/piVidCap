# %%
import cv2
import tensorflow.keras as tfkeras
import tensorflow as tf
print("Available devices:", tf.config.list_physical_devices())
import keras_ocr

pipeline = keras_ocr.pipeline.Pipeline()

testFile = '/media/chowder/abhiksFiles/personalData/wyzeCams/roomCamBy3dp/20201230/10/20.mp4'

cap = cv2.VideoCapture(testFile)
frames = []
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    x1, y1 = 1350, 1000  # Starting coordinates
    x2, y2 = 1900, 1080  # Ending coordinates
    cropped_frame = frame[y1:y2, x1:x2]
    frames.append(cropped_frame)
# Out:
# 2024-10-25 00:09:09.377353: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-25 00:09:09.381277: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-25 00:09:09.392506: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1729840149.409706 1927658 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1729840149.414923 1927658 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
#26 sec
prediction_groups = pipeline.recognize(frames[:60])
# Out:
# ...
# 5/5 [==============================] - 4s 791ms/step

# %%
#42 sec
prediction_groups = pipeline.recognize(frames[:100])
# Out:
# ...
# 7/7 [==============================] - 7s 939ms/step

# %%
prediction_groups = pipeline.recognize(frames[:200])

# %%
prediction_groups
# Out:
# [[('20201230',
#    array([[ 40.,  14.],
#           [293.,  14.],
#           [293.,  55.],
#           [ 40.,  55.]], dtype=float32)),
#   ('10119159',
#    array([[318.,  14.],
#           [518.,  14.],
#           [518.,  57.],
#           [318.,  57.]], dtype=float32))],
#  [('20201230',
#    array([[ 40.,  14.],
#           [293.,  14.],
#           [293.,  55.],
#           [ 40.,  55.]], dtype=float32)),
#   ('10119159',
#    array([[318.,  14.],
#           [518.,  14.],
#           [518.,  57.],
#           [318.,  57.]], dtype=float32))],
#  [('20201230',
#    array([[ 40.,  14.],
#           [293.,  14.],
#           [293.,  55.],
#           [ 40.,  55.]], dtype=float32)),
#   ('10120r00',
#    array([[318.,  14.],
#           [519.,  14.],
#           [519.,  56.],
#           [318.,  56.]], dtype=float32))],
#  [('20201230',
#    array([[ 40.,  14.],
#           [293.,  14.],
#           [293.,  55.],
#           [ 40.,  55.]], dtype=float32)),
#   ('10120600',
# ...

# %%
for text, box in prediction_groups[0]:
    print(f"Detected text: {text}, Bounding box: {box}")

# %%
import tensorflow as tf
print("Available devices:", tf.config.list_physical_devices())
# Out:
# Available devices: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
