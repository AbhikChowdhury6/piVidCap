# %%
import cv2
from datetime import datetime
import time
import pandas as pd

# Initialize the webcam (0 is the default camera)
timeBeforeCapDefined = datetime.now() 
cap = cv2.VideoCapture(1)
timeAfterCapDefined = datetime.now() 

cap.set(cv2.CAP_PROP_BUFFERSIZE, 1)

# Check if the webcam is opened correctly
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

initalFrameReadStart = datetime.now()
ret, frame = cap.read()
initalFrameReadEnd = datetime.now()
ret, frame = cap.read()

# %%
timeAfterCapDefined - timeBeforeCapDefined
# Out:
# datetime.timedelta(microseconds=266663)

# %%
initalFrameReadEnd - initalFrameReadStart
# Out:
# datetime.timedelta(seconds=1, microseconds=188891)

# %%
import torch.multiprocessing as mp
from modelWorker import model_worker
mp.set_start_method('spawn', force=True)

model_input_queue = mp.Queue()
model_output_queue = mp.Queue()

# Start the worker process
model_process = mp.Process(target=model_worker, args=(model_input_queue, model_output_queue))
model_process.start()

# time.sleep(1)
print(model_process.is_alive())
model_input_queue.put(frame)
result = model_output_queue.get()
print("Model output:", result)
# Out:
# True
# waiting for frame!
# Loading yolo11n-pose.torchscript for TorchScript inference...
#
# 0: 640x640 1 person, 5.6ms
# Speed: 3.8ms preprocess, 5.6ms inference, 174.9ms postprocess per image at shape (1, 3, 640, 640)
# waiting for frame!
# Model output: True

# %%
from multiprocessing import Process, Queue
from writerWorker import writer_worker

writer_input_queue = Queue()
writer_output_queue = Queue()

writer_process = Process(target=writer_worker, args=(writer_input_queue, writer_output_queue))
writer_process.start()
# Out:
# no device name set
# no device name set
# in writer worker

# %%
import time
import tzlocal

frameCount = 0


# wait till a round 15 seconds
currTime = datetime.now()
time.sleep((14 - (currTime.second % 15)) + (1 - currTime.microsecond/1_000_000))

readTimes = [datetime.now(tzlocal.get_localzone())]
ret, frame = cap.read()
mybuffer = [frame]
model_input_queue.put(frame)

def modelResult():
    if model_output_queue.empty(): print("waiting for processing")
    return model_output_queue.get()

def delayTill100ms():
    msToDelay = 100 - ((datetime.now().microsecond / 1000) % 100)
    time.sleep(msToDelay/1000)

while True:
    delayTill100ms()
    
    #logging and frame cap
    readTimes.append(datetime.now(tzlocal.get_localzone()))
    ret, frame = cap.read()
    mybuffer.append(frame)

    if datetime.now().second % 15 == 0 and datetime.now().microsecond < 100_000:
        # if there was people then save the last 15 seconds
        if modelResult():
            writer_input_queue.put((readTimes, mybuffer))
        else:
            # else just save the one frame analyzed for a timelapse
            writer_input_queue.put((readTimes,[mybuffer[0]]))
        
        
        delayTill100ms()
        readTimes = [datetime.now(tzlocal.get_localzone())]
        ret, frame = cap.read()
        mybuffer = [frame]
        model_input_queue.put(frame)


    frameCount += 1
# Out:
# got frame!
#
# 0: 640x640 1 person, 128.3ms
# Speed: 4.9ms preprocess, 128.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 101.8ms
# Speed: 6.6ms preprocess, 101.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 85.3ms
# Speed: 8.5ms preprocess, 85.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 251.7ms
# Speed: 10.1ms preprocess, 251.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 147.3ms
# Speed: 7.9ms preprocess, 147.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 134.4ms
# Speed: 18.1ms preprocess, 134.4ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 71.2ms
# Speed: 2.7ms preprocess, 71.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 117.1ms
# Speed: 2.0ms preprocess, 117.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 77.0ms
# Speed: 2.3ms preprocess, 77.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 71.3ms
# Speed: 1.4ms preprocess, 71.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 70.1ms
# Speed: 3.1ms preprocess, 70.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 70.6ms
# Speed: 1.7ms preprocess, 70.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 72.8ms
# Speed: 3.8ms preprocess, 72.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 75.8ms
# Speed: 4.0ms preprocess, 75.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 111.7ms
# Speed: 1.8ms preprocess, 111.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 81.7ms
# Speed: 4.5ms preprocess, 81.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 78.7ms
# Speed: 1.7ms preprocess, 78.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 76.1ms
# Speed: 4.9ms preprocess, 76.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 69.3ms
# Speed: 1.7ms preprocess, 69.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 93.6ms
# Speed: 2.6ms preprocess, 93.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 71.8ms
# Speed: 2.9ms preprocess, 71.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 72.7ms
# Speed: 1.8ms preprocess, 72.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 122.8ms
# Speed: 15.1ms preprocess, 122.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 77.8ms
# Speed: 2.1ms preprocess, 77.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 71.3ms
# Speed: 5.5ms preprocess, 71.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 80.7ms
# Speed: 3.2ms preprocess, 80.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 76.5ms
# Speed: 2.0ms preprocess, 76.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 84.3ms
# Speed: 7.2ms preprocess, 84.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 79.7ms
# Speed: 2.3ms preprocess, 79.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 81.2ms
# Speed: 1.7ms preprocess, 81.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 68.8ms
# Speed: 2.7ms preprocess, 68.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 75.9ms
# Speed: 2.2ms preprocess, 75.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 76.8ms
# Speed: 3.0ms preprocess, 76.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 78.0ms
# Speed: 5.1ms preprocess, 78.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 68.5ms
# Speed: 1.7ms preprocess, 68.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 76.8ms
# Speed: 3.7ms preprocess, 76.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 68.9ms
# Speed: 3.1ms preprocess, 68.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 105.3ms
# Speed: 2.0ms preprocess, 105.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# got frame!
#
# 0: 640x640 1 person, 94.1ms
# Speed: 6.1ms preprocess, 94.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# got results!
# waiting for frame!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 25
#      22     time.sleep(msToDelay/1000)
#      24 while True:
# ---> 25     delayTill100ms()
#      27     #logging and frame cap
#      28     readTimes.append(datetime.now(tzlocal.get_localzone()))
#
# Cell In[6], line 22, in delayTill100ms()
#      20 def delayTill100ms():
#      21     msToDelay = 100 - ((datetime.now().microsecond / 1000) % 100)
# ---> 22     time.sleep(msToDelay/1000)
#
# KeyboardInterrupt:

# %%
# Release the webcam and close the output file
cap.release()
output.release()

# %%
metaDf['timeBetweenReads'] =  metaDf['preReadTime'].shift(-1) - metaDf['preReadTime']
(metaDf['timeBetweenReads'].dt.total_seconds() * 1000).describe()
# Out:
# count    199.000000
# mean     100.000040
# std        0.353543
# min       96.995000
# 25%       99.996000
# 50%      100.000000
# 75%      100.005000
# max      103.005000
# Name: timeBetweenReads, dtype: float64

# %%
for e in metaDf['preReadTime'].tolist():
    print(e)
# Out:
# 2024-11-01 08:59:07.700074
# 2024-11-01 08:59:07.800073
# 2024-11-01 08:59:07.900072
# 2024-11-01 08:59:08.000073
# 2024-11-01 08:59:08.100188
# 2024-11-01 08:59:08.200069
# 2024-11-01 08:59:08.300065
# 2024-11-01 08:59:08.400065
# 2024-11-01 08:59:08.500073
# 2024-11-01 08:59:08.600184
# 2024-11-01 08:59:08.700077
# 2024-11-01 08:59:08.800075
# 2024-11-01 08:59:08.900122
# 2024-11-01 08:59:09.000077
# 2024-11-01 08:59:09.100074
# 2024-11-01 08:59:09.200074
# 2024-11-01 08:59:09.300074
# 2024-11-01 08:59:09.400070
# 2024-11-01 08:59:09.500074
# 2024-11-01 08:59:09.600064
# 2024-11-01 08:59:09.700073
# 2024-11-01 08:59:09.800077
# 2024-11-01 08:59:09.900079
# 2024-11-01 08:59:10.000077
# 2024-11-01 08:59:10.100073
# 2024-11-01 08:59:10.200081
